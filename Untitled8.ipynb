# %% [markdown]
# ### CAPSTONE PROJECT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %%
pip install requests beautifulsoup4 pandas lxml
# Out:
# ...
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import time
import random

# %% [markdown]
# ### WEB SCRAPPING

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

all_books = []

for page in range(1, 51):
    print(f"Scraping page {page}...")

    page_url = f"https://books.toscrape.com/catalogue/page-{page}.html"
    response = requests.get(page_url)
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("article", class_="product_pod")

    # 🔑 INNER LOOP (CRITICAL)
    for book in books:
        title = book.h3.a["title"]

        price = book.find("p", class_="price_color").text
        price = price.replace("Â£", "").replace("£", "").strip()
        price = float(price)

        rating = book.find("p", class_="star-rating")["class"][1]
        availability = book.find("p", class_="instock availability").text.strip()

        book_relative_url = book.h3.a["href"]
        book_url = "https://books.toscrape.com/catalogue/" + book_relative_url

        book_response = requests.get(book_url)
        book_soup = BeautifulSoup(book_response.text, "html.parser")

        category = book_soup.find("ul", class_="breadcrumb").find_all("a")[2].text.strip()

        all_books.append([
            title,
            price,
            rating,
            availability,
            category,
            book_url
        ])

books_df = pd.DataFrame(all_books, columns=[
    "Title", "Price", "Rating", "Availability", "Category", "Book_URL"
])

print("Total rows scraped:", books_df.shape[0])
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
# Scraping page 33...
# Scraping page 34...
# Scraping page 35...
# Scraping page 36...
# Scraping page 37...
# Scraping page 38...
# Scraping page 39...
# Scraping page 40...
# Scraping page 41...
# Scraping page 42...
# Scraping page 43...
# Scraping page 44...
# Scraping page 45...
# ...

# %%
books_df = pd.DataFrame(all_books, columns=[
    "Title",
    "Price",
    "Rating",
    "Availability",
    "Category",
    "Book_URL"
])

# %%
books_df.head()
# Out:
#                                    Title  Price Rating Availability  \
# 0                   A Light in the Attic  51.77  Three     In stock
# 1                     Tipping the Velvet  53.74    One     In stock
# 2                             Soumission  50.10    One     In stock
# 3                          Sharp Objects  47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  54.23   Five     In stock
#
#              Category                                           Book_URL
# 0              Poetry  https://books.toscrape.com/catalogue/a-light-i...
# 1  Historical Fiction  https://books.toscrape.com/catalogue/tipping-t...
# 2             Fiction  https://books.toscrape.com/catalogue/soumissio...
# 3             Mystery  https://books.toscrape.com/catalogue/sharp-obj...
# 4             History  https://books.toscrape.com/catalogue/sapiens-a...

# %%
books_df.shape
# Out:
# (1000, 6)

# %%
books_df.to_csv("books_with_category.csv", index=False)
print("CSV saved successfully!")
# Out:
# CSV saved successfully!

# %% [markdown]
# ### DATA UNDERSTANDING

# %%
books_df = pd.read_csv("books_with_category.csv")
books_df.head()
# Out:
#                                    Title  Price Rating Availability  \
# 0                   A Light in the Attic  51.77  Three     In stock
# 1                     Tipping the Velvet  53.74    One     In stock
# 2                             Soumission  50.10    One     In stock
# 3                          Sharp Objects  47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  54.23   Five     In stock
#
#              Category                                           Book_URL
# 0              Poetry  https://books.toscrape.com/catalogue/a-light-i...
# 1  Historical Fiction  https://books.toscrape.com/catalogue/tipping-t...
# 2             Fiction  https://books.toscrape.com/catalogue/soumissio...
# 3             Mystery  https://books.toscrape.com/catalogue/sharp-obj...
# 4             History  https://books.toscrape.com/catalogue/sapiens-a...

# %%
books_df.shape
# Out:
# (1000, 6)

# %%
books_df.describe()
# Out:
#             Price
# count  1000.00000
# mean     35.07035
# std      14.44669
# min      10.00000
# 25%      22.10750
# 50%      35.98000
# 75%      47.45750
# max      59.99000

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         1000 non-null   object
#  1   Price         1000 non-null   float64
#  2   Rating        1000 non-null   object
#  3   Availability  1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Book_URL      1000 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 47.0+ KB

# %%
books_df.isnull()
# Out:
#      Title  Price  Rating  Availability  Category  Book_URL
# 0    False  False   False         False     False     False
# 1    False  False   False         False     False     False
# 2    False  False   False         False     False     False
# 3    False  False   False         False     False     False
# 4    False  False   False         False     False     False
# ..     ...    ...     ...           ...       ...       ...
# 995  False  False   False         False     False     False
# 996  False  False   False         False     False     False
# 997  False  False   False         False     False     False
# 998  False  False   False         False     False     False
# 999  False  False   False         False     False     False
#
# [1000 rows x 6 columns]

# %%
books_df.isnull().sum()
# Out:
# Title           0
# Price           0
# Rating          0
# Availability    0
# Category        0
# Book_URL        0
# dtype: int64

# %%
books_df["Price"] = books_df["Price"].astype(float)

# %%
rating_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}

books_df["Rating"] = books_df["Rating"].map(rating_map)

# %%
books_df["Title"] = books_df["Title"].str.title()
books_df["Category"] = books_df["Category"].str.title()

# %%
books_df.dtypes
# Out:
# Title            object
# Price           float64
# Rating            int64
# Availability     object
# Category         object
# Book_URL         object
# dtype: object

# %%
books_df.to_csv("books_cleaned.csv", index=False)
print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
plt.figure()
plt.hist(df["Price"])
plt.xlabel("Price")
plt.ylabel("Count")
plt.title("Distribution of Book Prices")
plt.show()

# %%
plt.figure()
sns.countplot(x="Rating", data=df,color='purple')
plt.title("Rating Distribution")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="Category", y="Price", data=df,color='brown')
plt.xticks(rotation=90)
plt.title("Average Price by Category")
plt.show()

# %%
df["Category"].value_counts().head(10)
# Out:
# Category
# Default           152
# Nonfiction        110
# Sequential Art     75
# Add a comment      67
# Fiction            65
# Young Adult        54
# Fantasy            48
# Romance            35
# Mystery            32
# Food and Drink     30
# Name: count, dtype: int64

# %%
books_df.groupby("Category")["Price"].agg(["mean", "min", "max", "count"]).sort_values(by="mean", ascending=False)
# Out:
#                          mean    min    max  count
# Category
# Suspense            58.330000  58.33  58.33      1
# Novels              54.810000  54.81  54.81      1
# Politics            53.613333  51.33  56.86      3
# Health              51.452500  49.05  54.07      4
# New Adult           46.383333  36.29  58.35      6
# Christian           42.496667  25.77  54.00      3
# Sports And Games    41.166000  24.42  51.22      5
# Self Help           40.620000  12.08  52.15      5
# Travel              39.794545  23.21  56.88     11
# Fantasy             39.593958  12.16  58.75     48
# Art                 38.520000  10.29  49.05      8
# Parenting           37.350000  37.35  37.35      1
# History             37.295000  11.45  59.64     18
# Autobiography       37.053333  10.93  59.04      9
# Womens Fiction      36.791176  13.73  57.36     17
# Cultural            36.580000  36.58  36.58      1
# Classics            36.545263  14.82  58.63     19
# ...

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y=books_df["Price"],color='magenta')
plt.title("Price Outliers in Books")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="Rating", y="Price", data=df,color='green')
plt.title("Price vs Rating")
plt.xlabel("Rating")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="Category", data=df, order=df["Category"].value_counts().index,color='red')
plt.xticks(rotation=90)
plt.title("Number of Books per Category")
plt.show()

# %%
df.sort_values(by="Price", ascending=False).head(10)[["Title", "Category", "Price", "Rating"]]
# Out:
#                                                  Title        Category  Price  \
# 648                 The Perfect Play (Play by Play #1)         Romance  59.99
# 617                  Last One Home (New Beginnings #1)         Fiction  59.98
# 860                   Civilization and Its Discontents      Psychology  59.95
# 560                     The Barefoot Contessa Cookbook  Food and Drink  59.92
# 366                          The Diary of a Young Girl      Nonfiction  59.90
# 657  The Bone Hunters (Lexy Vaughan & Steven Macaul...        Thriller  59.71
# 133  Thomas Jefferson and the Tripoli Pirates: The ...         History  59.64
# 387                      Boar Island (Anna Pigeon #19)         Mystery  59.48
# 549  The Man Who Mistook His Wife for a Hat and Oth...      Nonfiction  59.45
# 393                          The Improbability of Love         Fiction  59.45
#
#      Rating
# 648       3
# 617       3
# 860       2
# 560       5
# 366       3
# 657       3
# 133       1
# ...

# %%
df.sort_values(by="Price").head(10)[["Title", "Category", "Price", "Rating"]]
# Out:
#                                                  Title        Category  Price  \
# 638                         An Abundance of Katherines     Young Adult  10.00
# 501                              The Origin of Species         Science  10.01
# 716  The Tipping Point: How Little Things Can Make ...   Add a comment  10.02
# 84                                            Patience  Sequential Art  10.16
# 302                               Greek Mythic History         Default  10.23
# 558  The Fellowship of the Ring (The Lord of the Ri...         Default  10.27
# 479                                  History of Beauty             Art  10.29
# 242  The Lucifer Effect: Understanding How Good Peo...      Psychology  10.40
# 434  NaNo What Now? Finding your editing process, r...         Default  10.41
# 274                                       Pet Sematary          Horror  10.56
#
#      Rating
# 638       5
# 501       4
# 716       2
# 84        3
# 302       5
# 558       2
# 479       4
# ...

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[["Price", "Rating"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Price and Rating")
plt.show()

# %%
rating_category = pd.crosstab(df["Category"], df["Rating"])
rating_category.head()
# Out:
# Rating          1   2   3   4  5
# Category
# Academic        0   1   0   0  0
# Add a comment  16  13  17  13  8
# Adult Fiction   0   0   0   0  1
# Art             0   1   2   4  1
# Autobiography   2   3   0   1  3

# %%
rating_category.plot(kind="bar", stacked=True, figsize=(12,6))
plt.title("Ratings Distribution Across Categories")
plt.ylabel("Count")
plt.show()

# %%
df["Availability"].value_counts()
# Out:
# Availability
# In stock    1000
# Name: count, dtype: int64

# %%
plt.figure()
df["Availability"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Availability Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x="Category", y="Price", data=df)
plt.xticks(rotation=90)
plt.title("Price Distribution by Category")
plt.show()

# %%
df.groupby("Category")["Rating"].mean().sort_values(ascending=False)
# Out:
# Category
# Erotica               5.000000
# Adult Fiction         5.000000
# Novels                5.000000
# Christian Fiction     4.166667
# Health                3.750000
# Art                   3.625000
# Poetry                3.526316
# Humor                 3.400000
# Spirituality          3.333333
# Young Adult           3.296296
# Historical Fiction    3.230769
# Fiction               3.184615
# New Adult             3.166667
# Music                 3.153846
# Religion              3.142857
# Womens Fiction        3.117647
# Fantasy               3.083333
# Autobiography         3.000000
# Suspense              3.000000
# Historical            3.000000
# Sports and Games      3.000000
# Sequential Art        2.973333
# History               2.944444
# Mystery               2.937500
# Science               2.928571
# Business              2.916667
# Food and Drink        2.900000
# Nonfiction            2.881818
# Default               2.835526
# ...

# %%
sns.pairplot(df[["Price", "Rating"]])
plt.show()

# %%
pip install sqlalchemy
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: sqlalchemy in c:\users\vaishnavi.v\anaconda3\lib\site-packages (2.0.39)
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///books_database.db")

# %%
df.to_sql("books", con=engine, if_exists="replace", index=False)
print("Data successfully stored in database!")
# Out:
# Data successfully stored in database!

# %%
df = pd.read_csv("books_cleaned.csv")
df.head()
# Out:
#                                    Title  Price  Rating Availability  \
# 0                   A Light In The Attic  51.77       3     In stock
# 1                     Tipping The Velvet  53.74       1     In stock
# 2                             Soumission  50.10       1     In stock
# 3                          Sharp Objects  47.82       4     In stock
# 4  Sapiens: A Brief History Of Humankind  54.23       5     In stock
#
#              Category                                           Book_URL
# 0              Poetry  https://books.toscrape.com/catalogue/a-light-i...
# 1  Historical Fiction  https://books.toscrape.com/catalogue/tipping-t...
# 2             Fiction  https://books.toscrape.com/catalogue/soumissio...
# 3             Mystery  https://books.toscrape.com/catalogue/sharp-obj...
# 4             History  https://books.toscrape.com/catalogue/sapiens-a...

# %%
from sqlalchemy import create_engine

engine = create_engine("sqlite:///books_database.db")

df.to_sql("books", con=engine, if_exists="replace", index=False)

print("Data successfully stored in database!")
# Out:
# Data successfully stored in database!

# %%
query = "SELECT * FROM books"
db_df = pd.read_sql(query, engine)

db_df.head()
# Out:
#                                    Title  Price  Rating Availability  \
# 0                   A Light In The Attic  51.77       3     In stock
# 1                     Tipping The Velvet  53.74       1     In stock
# 2                             Soumission  50.10       1     In stock
# 3                          Sharp Objects  47.82       4     In stock
# 4  Sapiens: A Brief History Of Humankind  54.23       5     In stock
#
#              Category                                           Book_URL
# 0              Poetry  https://books.toscrape.com/catalogue/a-light-i...
# 1  Historical Fiction  https://books.toscrape.com/catalogue/tipping-t...
# 2             Fiction  https://books.toscrape.com/catalogue/soumissio...
# 3             Mystery  https://books.toscrape.com/catalogue/sharp-obj...
# 4             History  https://books.toscrape.com/catalogue/sapiens-a...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
X = db_df[["Price", "Rating"]]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure()
plt.plot(range(1, 11), wcss, marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method for Optimal K")
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# %%
db_df["Cluster"] = clusters
db_df.head()
# Out:
#                                    Title  Price  Rating Availability  \
# 0                   A Light In The Attic  51.77       3     In stock
# 1                     Tipping The Velvet  53.74       1     In stock
# 2                             Soumission  50.10       1     In stock
# 3                          Sharp Objects  47.82       4     In stock
# 4  Sapiens: A Brief History Of Humankind  54.23       5     In stock
#
#              Category                                           Book_URL  \
# 0              Poetry  https://books.toscrape.com/catalogue/a-light-i...
# 1  Historical Fiction  https://books.toscrape.com/catalogue/tipping-t...
# 2             Fiction  https://books.toscrape.com/catalogue/soumissio...
# 3             Mystery  https://books.toscrape.com/catalogue/sharp-obj...
# 4             History  https://books.toscrape.com/catalogue/sapiens-a...
#
#    Cluster
# 0        2
# 1        2
# 2        1
# 3        2
# 4        2

# %%
plt.figure()
plt.scatter(db_df["Price"], db_df["Rating"], c=db_df["Cluster"])
plt.xlabel("Price")
plt.ylabel("Rating")
plt.title("Book Clusters based on Price & Rating")
plt.show()

# %%
db_df.groupby("Cluster")[["Price", "Rating"]].mean()
# Out:
#              Price    Rating
# Cluster
# 0        23.776309  4.034700
# 1        29.686049  1.407295
# 2        50.187994  3.336158

# %% [markdown]
# ### MODEL TRAINING

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
df = pd.read_csv("books_cleaned.csv")

# %%
X = df[["Price", "Rating"]]
y = df["Category"]

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
category_counts = df['Category'].value_counts()

valid_categories = category_counts[category_counts >= 2].index

df = df[df['Category'].isin(valid_categories)]

# %%
X = df[['Price', 'Rating']]
y = df['Category']

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_encoded = le.fit_transform(y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### MODEL 1: LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_scaled, y_train)

y_pred_lr = lr.predict(X_test_scaled)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
print("F1 Score:", f1_score(y_test, y_pred_lr, average="weighted"))
# Out:
# Logistic Regression Accuracy: 0.15656565656565657
# F1 Score: 0.04238895505271051

# %% [markdown]
# ### MODEL 2: SUPPORT VECTOR MACHINE (SVM)

# %%
from sklearn.svm import SVC

svm = SVC(kernel="rbf")
svm.fit(X_train_scaled, y_train)

y_pred_svm = svm.predict(X_test_scaled)

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print("F1 Score:", f1_score(y_test, y_pred_svm, average="weighted"))
# Out:
# SVM Accuracy: 0.15656565656565657
# F1 Score: 0.04238895505271051

# %% [markdown]
# ### MODEL 3: k-NEAREST NEIGHBORS (k-NN)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_pred_knn = knn.predict(X_test_scaled)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print("F1 Score:", f1_score(y_test, y_pred_knn, average="weighted"))
# Out:
# KNN Accuracy: 0.06060606060606061
# F1 Score: 0.0498673240339907

# %% [markdown]
# ### MODEL 4: RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf, average="weighted"))
# Out:
# Random Forest Accuracy: 0.05555555555555555
# F1 Score: 0.05198659392396589

# %% [markdown]
# ### MODEL 5: XGBOOST

# %%
pip install xgboost
# Out:
# ...
#
# ...

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    objective="multi:softmax",
    num_class=len(np.unique(y_encoded)),
    eval_metric="mlogloss"
)

xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_test)

print("XGBoost Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("F1 Score:", f1_score(y_test, y_pred_xgb, average="weighted"))
# Out:
# XGBoost Accuracy: 0.045454545454545456
# F1 Score: 0.04212924286023701

# %%
results = pd.DataFrame({
    "Model": ["Logistic Regression", "SVM", "KNN", "Random Forest", "XGBoost"],
    "Accuracy": [
        accuracy_score(y_test, y_pred_lr),
        accuracy_score(y_test, y_pred_svm),
        accuracy_score(y_test, y_pred_knn),
        accuracy_score(y_test, y_pred_rf),
        accuracy_score(y_test, y_pred_xgb)
    ],
    "F1 Score": [
        f1_score(y_test, y_pred_lr, average="weighted"),
        f1_score(y_test, y_pred_svm, average="weighted"),
        f1_score(y_test, y_pred_knn, average="weighted"),
        f1_score(y_test, y_pred_rf, average="weighted"),
        f1_score(y_test, y_pred_xgb, average="weighted")
    ]
})

results
# Out:
#                  Model  Accuracy  F1 Score
# 0  Logistic Regression  0.156566  0.042389
# 1                  SVM  0.156566  0.042389
# 2                  KNN  0.060606  0.049867
# 3        Random Forest  0.055556  0.051987
# 4              XGBoost  0.045455  0.042129

# %%
from sklearn.metrics import accuracy_score, classification_report

models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=42)
}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(f"\n{name}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy: 0.15656565656565657
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#            8       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         1
#           10       0.16      1.00      0.27        31
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        13
#           13       0.00      0.00      0.00         6
#           14       0.00      0.00      0.00         1
# ...

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.00      0.00      0.00         2
#            2       0.33      0.50      0.40         2
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#            8       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         1
#           10       0.14      0.16      0.15        31
#           11       0.00      0.00      0.00        10
#           12       0.08      0.08      0.08        13
#           13       0.00      0.00      0.00         6
#           14       0.00      0.00      0.00         1
#           16       0.00      0.00      0.00         5
# ...

# %%
results_df = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "SVM",
        "KNN",
        "Random Forest",
        "XGBoost"
    ],
    "Accuracy": [
        0.1566,
        0.1566,
        0.0606,
        0.0556,
        0.0455
    ],
    "F1 Score": [
        0.04239,
        0.04239,
        0.04987,
        0.05199,
        0.04213
    ]
})

results_df
# Out:
#                  Model  Accuracy  F1 Score
# 0  Logistic Regression    0.1566   0.04239
# 1                  SVM    0.1566   0.04239
# 2                  KNN    0.0606   0.04987
# 3        Random Forest    0.0556   0.05199
# 4              XGBoost    0.0455   0.04213

# %%
plt.figure()
plt.bar(results_df["Model"], results_df["Accuracy"],color='orange')
plt.xticks(rotation=45)
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.title("Model Comparison based on Accuracy")
plt.show()

# %%
plt.figure()
plt.bar(results_df["Model"], results_df["F1 Score"],color='yellow')
plt.xticks(rotation=45)
plt.xlabel("Model")
plt.ylabel("F1 Score (Weighted)")
plt.title("Model Comparison based on F1 Score")
plt.show()

# %%
x = np.arange(len(results_df["Model"]))
width = 0.35

plt.figure()
plt.bar(x - width/2, results_df["Accuracy"], width, label="Accuracy")
plt.bar(x + width/2, results_df["F1 Score"], width, label="F1 Score")

plt.xticks(x, results_df["Model"], rotation=45)
plt.xlabel("Model")
plt.ylabel("Score")
plt.title("Accuracy vs F1 Score Comparison of Models")
plt.legend()
plt.show()

# %% [markdown]
# ### Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
print("Best Parameters:")
print(grid_search.best_params_)
# Out:
# Best Parameters:
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}

# %%
print("Best Cross-Validation Accuracy:")
print(grid_search.best_score_)
# Out:
# Best Cross-Validation Accuracy:
# 0.12620014330069262

# %%
best_model = grid_search.best_estimator_
best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                        random_state=42)

# %%
y_pred = best_model.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.050505050505050504
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#            8       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         1
#           10       0.09      0.19      0.12        31
#           11       0.17      0.20      0.18        10
#           12       0.06      0.08      0.07        13
#           13       0.00      0.00      0.00         6
#           14       0.00      0.00      0.00         1
#           16       0.00      0.00      0.00         5
# ...

# %%
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_grid,
    n_iter=20,
    cv=5,
    scoring='accuracy',
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [None, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    random_state=42, scoring='accuracy')

# %%
best_model = random_search.best_estimator_
best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=200, random_state=42)
